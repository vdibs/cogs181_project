# %% [markdown]
# ### char-rnn-tensorflow try 1
#
# DEFAULTS
#     hidden state size: 128
#     number of layers: 2
#     model type: lstm
#     minibatch size: 50
#     rnn sequence length: 50
#     number of epochs: 50
#     clip gradients: 5
#     learning rate: .002
#     decay rate for rmsporp: .97

# %%
from scipy.misc import imread
from matplotlib.pyplot import imshow
from scipy.misc import imresize
# %pylab inline
from scipy.ndimage import rotate

img11 = imread('tf_1.1.png')
pylab.rcParams['figure.figsize'] = (40, 12)
img11 = plt.imshow(img11)
img11
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
img12 = imread('tf_1.2.png')
pylab.rcParams['figure.figsize'] = (40, 12)
img12 = plt.imshow(img12)
img12

# %% [markdown]
# It understands most spacing, most syntax, common words in Trump's vocabulary, but a lot of the words are wrong.
